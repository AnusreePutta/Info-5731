# %% [markdown]
# <a href="https://colab.research.google.com/github/AnusreePutta/Info-5731/blob/main/Putta_Anusree_Assignment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment 2**
#
# In this assignment, you will work on gathering text data from an open data source via web scraping or API. Following this, you will need to clean the text data and perform syntactic analysis on the data. Follow the instructions carefully and design well-structured Python programs to address each question.
#
# **Expectations**:
# *   Use the provided .*ipynb* document to write your code & respond to the questions. Avoid generating a new file.
# *   Write complete answers and run all the cells before submission.
# *   Make sure the submission is "clean"; *i.e.*, no unnecessary code cells.
# *   Once finished, allow shared rights from top right corner (*see Canvas for details*).
#
# * **Make sure to submit the cleaned data CSV in the comment section - 10 points**
#
# **Total points**: 100
#
# **Deadline**: Wednesday, at 11:59 PM.
#
# **Late Submission will have a penalty of 10% reduction for each day after the deadline.**

# %% [markdown]
# # Question 1 (40 points)
#
# Write a python program to collect text data from **either of the following sources** and save the data into a **csv file:**
#
# (1) Collect all the customer reviews of a product (you can choose any porduct) on amazon. [atleast 1000 reviews]
#
# (2) Collect the top 1000 User Reviews of a movie recently in 2023 or 2024 (you can choose any movie) from IMDB. [If one movie doesn't have sufficient reviews, collect reviews of atleast 2 or 3 movies]
#
# (3) Collect all the reviews of the top 1000 most popular software from G2 or Capterra.
#
# (4) Collect the **abstracts** of the top 10000 research papers by using the query "machine learning", "data science", "artifical intelligence", or "information extraction" from Semantic Scholar.
#
# (5) Collect all the information of the 904 narrators in the Densho Digital Repository.

# %%
# Your code hereimport requests
import requests
from bs4 import BeautifulSoup
import csv

def fetch_reviews(imdb_id):
    reviews = []
    url = f"https://www.imdb.com/title/tt1517268/reviews?ref_=tt_urv"
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    # Assuming each review is within a 'div' tag with a specific class.
    # This is a placeholder and might need adjustment based on actual page structure.
    review_divs = soup.find_all('div', class_='review-container')
    for div in review_divs:
        title = div.find('a', class_='title').text.strip()
        text = div.find('div', class_='text show-more__control').text.strip()
        try:
            rating = div.find('span', class_='rating-other-user-rating').span.text.strip()
        except AttributeError:
            rating = 'No Rating'

        reviews.append({'review_title': title, 'review_text': text, 'rating': rating})

    return reviews

def save_reviews_to_csv(reviews, filename):
    with open(filename, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.DictWriter(file, fieldnames=['review_title', 'review_text', 'rating'])
        writer.writeheader()
        for review in reviews:
            writer.writerow(review)

# Example usage
imdb_id = 'tt66547321'  # Example IMDb ID
reviews = fetch_reviews(imdb_id)
save_reviews_to_csv(reviews, 'barbie_reviews.csv')

# %% [markdown]
# # Question 2 (30 points)
#
# Write a python program to **clean the text data** you collected in the previous question and save the clean data in a new column in the csv file. The data cleaning steps include: [Code and output is required for each part]
#
# (1) Remove noise, such as special characters and punctuations.
#
# (2) Remove numbers.
#
# (3) Remove stopwords by using the stopwords list.
#
# (4) Lowercase all texts
#
# (5) Stemming.
#
# (6) Lemmatization.

# %%
# Write code for each of the sub parts with proper comments.
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer

df = pd.read_csv('barbie_reviews.csv')
df
# Out:
#                                          review_title  \
# 0                      Beautiful film, but so preachy
# 1                                     A Hot Pink Mess
# 2     Could Have Been Great. 2nd Half Brings It Down.
# 3     As a guy I felt some discomfort, and that's ok.
# 4                                    Too heavy handed
# 5            Well this really did come as a surprise.
# 6       3 reasons FOR seeing it and 1 reason AGAINST.
# 7                                   It was depressing
# 8   My mom and I saw this yesterday. Here are my t...
# 9   The marketing was more entertaining than the a...
# 10                     Barbie Is A Weirdly Fun Movie!
# 11  Brilliant observations, but social depth is mi...
# 12                         Somewhat of a Jumbled Mess
# 13                      Fun and surprisingly touching
# 14                      Strong Start... and That's It
# 15                        Boring, mind-numbing drivel
# 16                                A Technicolor Dream
# 17                     Didn't live up to expectations
# 18                                    You are Kenough
# 19                                          OVERHYPED
# 20  Disappointing: terribly preachy and horrendous...
# 21                                     Ken out of ten
# 22  I would have preferred to see this as a 30 min...
# 23                                Not what I Expected
# 24              Honestly - not funny and light enough
#
#                                           review_text     rating
# 0   Margot does the best with what she's given, bu...          6
# 1   Before making Barbie (2023), Greta Gerwig sing...          6
# 2   The quality, the humor, and the writing of the...          6
# 3   As much as it pains me to give a movie called ...         10
# 4   As a woman that grew up with Barbie, I was ver...          6
# 5   It pains me to say it, but I enjoyed this movi...          8
# 6   The first reason to go see it:It's good fun. I...          7
# 7   I thought this would be so much different. The...          8
# 8   I don't know if I put spoilers in here. I am s...          6
# 9   I went to see this today, everyone in my group...          4
# 10  8.5/10\nWhile i'm not so sure at first, the mo...          8
# 11  Greta Gerwig and Noah Baumbach have a knack fo...          6
# 12  My 15-year old daughter wrote the following re...          5
# 13  I was honestly doubting this movie at first, b...          8
# 14  I walked out of the theatre thinking, "Yeah, I...          6
# 15  I do not usually write reviews, but this is be...  No Rating
# 16  Wow, this movie was a love letter to cinema. F...          9
# 17  I watched this with my wife who was ready to t...          6
# 18  This movie is so much fun. It starts off reall...          8
# 19  This is a movie that was way overhyped. Everyo...          6
# 20  Margot Robbie and Ryan Gosling are really grea...          3
# 21  Wow. I did not see this masterpiece coming. An...         10
# 22  Mrs. Shullivan and I enjoyed about the first 3...          6
# 23  I played with barbies a lot as a kid, so I tho...          5
# 24  I really enjoyed the first 20 minutes of the m...  No Rating

# %%
df['noise_removed'] = df['review_text'].apply(lambda x: re.sub(r'[^\w\s]', '', x))
df.head()
# Out:
#                                       review_title  \
# 0                   Beautiful film, but so preachy
# 1                                  A Hot Pink Mess
# 2  Could Have Been Great. 2nd Half Brings It Down.
# 3  As a guy I felt some discomfort, and that's ok.
# 4                                 Too heavy handed
#
#                                          review_text rating  \
# 0  Margot does the best with what she's given, bu...      6
# 1  Before making Barbie (2023), Greta Gerwig sing...      6
# 2  The quality, the humor, and the writing of the...      6
# 3  As much as it pains me to give a movie called ...     10
# 4  As a woman that grew up with Barbie, I was ver...      6
#
#                                        noise_removed
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie 2023 Greta Gerwig singleh...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...

# %%
df['numbers_removed'] = df['noise_removed'].apply(lambda x: re.sub(r'\d+', '', x))
df.head()
# Out:
#                                       review_title  \
# 0                   Beautiful film, but so preachy
# 1                                  A Hot Pink Mess
# 2  Could Have Been Great. 2nd Half Brings It Down.
# 3  As a guy I felt some discomfort, and that's ok.
# 4                                 Too heavy handed
#
#                                          review_text rating  \
# 0  Margot does the best with what she's given, bu...      6
# 1  Before making Barbie (2023), Greta Gerwig sing...      6
# 2  The quality, the humor, and the writing of the...      6
# 3  As much as it pains me to give a movie called ...     10
# 4  As a woman that grew up with Barbie, I was ver...      6
#
#                                        noise_removed  \
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie 2023 Greta Gerwig singleh...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...
#
#                                      numbers_removed
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie  Greta Gerwig singlehande...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...

# %%
df['lowercased'] = df['numbers_removed'].apply(lambda x: x.lower())
df.head()
# Out:
#                                       review_title  \
# 0                   Beautiful film, but so preachy
# 1                                  A Hot Pink Mess
# 2  Could Have Been Great. 2nd Half Brings It Down.
# 3  As a guy I felt some discomfort, and that's ok.
# 4                                 Too heavy handed
#
#                                          review_text rating  \
# 0  Margot does the best with what she's given, bu...      6
# 1  Before making Barbie (2023), Greta Gerwig sing...      6
# 2  The quality, the humor, and the writing of the...      6
# 3  As much as it pains me to give a movie called ...     10
# 4  As a woman that grew up with Barbie, I was ver...      6
#
#                                        noise_removed  \
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie 2023 Greta Gerwig singleh...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...
#
#                                      numbers_removed  \
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie  Greta Gerwig singlehande...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...
#
#                                           lowercased
# 0  margot does the best with what shes given but ...
# 1  before making barbie  greta gerwig singlehande...
# 2  the quality the humor and the writing of the m...
# 3  as much as it pains me to give a movie called ...
# 4  as a woman that grew up with barbie i was very...

# %%
stop_words = set(stopwords.words('english'))
df['stopwords_removed'] = df['lowercased'].apply(lambda x: ' '.join([word for word in x.split() if word not in stop_words]))
df.head()
# Out:
#                                       review_title  \
# 0                   Beautiful film, but so preachy
# 1                                  A Hot Pink Mess
# 2  Could Have Been Great. 2nd Half Brings It Down.
# 3  As a guy I felt some discomfort, and that's ok.
# 4                                 Too heavy handed
#
#                                          review_text rating  \
# 0  Margot does the best with what she's given, bu...      6
# 1  Before making Barbie (2023), Greta Gerwig sing...      6
# 2  The quality, the humor, and the writing of the...      6
# 3  As much as it pains me to give a movie called ...     10
# 4  As a woman that grew up with Barbie, I was ver...      6
#
#                                        noise_removed  \
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie 2023 Greta Gerwig singleh...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...
#
#                                      numbers_removed  \
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie  Greta Gerwig singlehande...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...
#
#                                           lowercased  \
# 0  margot does the best with what shes given but ...
# 1  before making barbie  greta gerwig singlehande...
# 2  the quality the humor and the writing of the m...
# 3  as much as it pains me to give a movie called ...
# 4  as a woman that grew up with barbie i was very...
#
#                                    stopwords_removed
# 0  margot best shes given film disappointing mark...
# 1  making barbie greta gerwig singlehandedly dire...
# 2  quality humor writing movie fun quirky unique ...
# 3  much pains give movie called barbie brilliantl...
# 4  woman grew barbie excited movie curious see wo...

# %%
ps = PorterStemmer()
df['stemmed'] = df['stopwords_removed'].apply(lambda x: ' '.join([ps.stem(word) for word in x.split()]))
df.head()
# Out:
#                                       review_title  \
# 0                   Beautiful film, but so preachy
# 1                                  A Hot Pink Mess
# 2  Could Have Been Great. 2nd Half Brings It Down.
# 3  As a guy I felt some discomfort, and that's ok.
# 4                                 Too heavy handed
#
#                                          review_text rating  \
# 0  Margot does the best with what she's given, bu...      6
# 1  Before making Barbie (2023), Greta Gerwig sing...      6
# 2  The quality, the humor, and the writing of the...      6
# 3  As much as it pains me to give a movie called ...     10
# 4  As a woman that grew up with Barbie, I was ver...      6
#
#                                        noise_removed  \
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie 2023 Greta Gerwig singleh...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...
#
#                                      numbers_removed  \
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie  Greta Gerwig singlehande...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...
#
#                                           lowercased  \
# 0  margot does the best with what shes given but ...
# 1  before making barbie  greta gerwig singlehande...
# 2  the quality the humor and the writing of the m...
# 3  as much as it pains me to give a movie called ...
# 4  as a woman that grew up with barbie i was very...
#
#                                    stopwords_removed  \
# 0  margot best shes given film disappointing mark...
# 1  making barbie greta gerwig singlehandedly dire...
# 2  quality humor writing movie fun quirky unique ...
# 3  much pains give movie called barbie brilliantl...
# 4  woman grew barbie excited movie curious see wo...
#
#                                              stemmed
# 0  margot best she given film disappoint market f...
# 1  make barbi greta gerwig singlehandedli direct ...
# 2  qualiti humor write movi fun quirki uniqu get ...
# 3  much pain give movi call barbi brilliantli han...
# 4  woman grew barbi excit movi curiou see would e...

# %%
lemmatizer = WordNetLemmatizer()
df['lemmatized'] = df['stemmed'].apply(lambda x: ' '.join([lemmatizer.lemmatize(word) for word in x.split()]))
df.head()
# Out:
#                                       review_title  \
# 0                   Beautiful film, but so preachy
# 1                                  A Hot Pink Mess
# 2  Could Have Been Great. 2nd Half Brings It Down.
# 3  As a guy I felt some discomfort, and that's ok.
# 4                                 Too heavy handed
#
#                                          review_text rating  \
# 0  Margot does the best with what she's given, bu...      6
# 1  Before making Barbie (2023), Greta Gerwig sing...      6
# 2  The quality, the humor, and the writing of the...      6
# 3  As much as it pains me to give a movie called ...     10
# 4  As a woman that grew up with Barbie, I was ver...      6
#
#                                        noise_removed  \
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie 2023 Greta Gerwig singleh...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...
#
#                                      numbers_removed  \
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie  Greta Gerwig singlehande...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...
#
#                                           lowercased  \
# 0  margot does the best with what shes given but ...
# 1  before making barbie  greta gerwig singlehande...
# 2  the quality the humor and the writing of the m...
# 3  as much as it pains me to give a movie called ...
# 4  as a woman that grew up with barbie i was very...
#
#                                    stopwords_removed  \
# 0  margot best shes given film disappointing mark...
# 1  making barbie greta gerwig singlehandedly dire...
# 2  quality humor writing movie fun quirky unique ...
# 3  much pains give movie called barbie brilliantl...
# 4  woman grew barbie excited movie curious see wo...
#
#                                              stemmed  \
# 0  margot best she given film disappoint market f...
# 1  make barbi greta gerwig singlehandedli direct ...
# 2  qualiti humor write movi fun quirki uniqu get ...
# 3  much pain give movi call barbi brilliantli han...
# 4  woman grew barbi excit movi curiou see would e...
#
#                                           lemmatized
# 0  margot best she given film disappoint market f...
# 1  make barbi greta gerwig singlehandedli direct ...
# 2  qualiti humor write movi fun quirki uniqu get ...
# 3  much pain give movi call barbi brilliantli han...
# 4  woman grew barbi excit movi curiou see would e...

# %%
df['cleaned_review'] = df['lemmatized']
df.head()
# Out:
#                                       review_title  \
# 0                   Beautiful film, but so preachy
# 1                                  A Hot Pink Mess
# 2  Could Have Been Great. 2nd Half Brings It Down.
# 3  As a guy I felt some discomfort, and that's ok.
# 4                                 Too heavy handed
#
#                                          review_text rating  \
# 0  Margot does the best with what she's given, bu...      6
# 1  Before making Barbie (2023), Greta Gerwig sing...      6
# 2  The quality, the humor, and the writing of the...      6
# 3  As much as it pains me to give a movie called ...     10
# 4  As a woman that grew up with Barbie, I was ver...      6
#
#                                        noise_removed  \
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie 2023 Greta Gerwig singleh...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...
#
#                                      numbers_removed  \
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie  Greta Gerwig singlehande...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...
#
#                                           lowercased  \
# 0  margot does the best with what shes given but ...
# 1  before making barbie  greta gerwig singlehande...
# 2  the quality the humor and the writing of the m...
# 3  as much as it pains me to give a movie called ...
# 4  as a woman that grew up with barbie i was very...
#
#                                    stopwords_removed  \
# 0  margot best shes given film disappointing mark...
# 1  making barbie greta gerwig singlehandedly dire...
# 2  quality humor writing movie fun quirky unique ...
# 3  much pains give movie called barbie brilliantl...
# 4  woman grew barbie excited movie curious see wo...
#
#                                              stemmed  \
# 0  margot best she given film disappoint market f...
# 1  make barbi greta gerwig singlehandedli direct ...
# 2  qualiti humor write movi fun quirki uniqu get ...
# 3  much pain give movi call barbi brilliantli han...
# 4  woman grew barbi excit movi curiou see would e...
#
#                                           lemmatized  \
# 0  margot best she given film disappoint market f...
# 1  make barbi greta gerwig singlehandedli direct ...
# 2  qualiti humor write movi fun quirki uniqu get ...
# 3  much pain give movi call barbi brilliantli han...
# 4  woman grew barbi excit movi curiou see would e...
#
#                                       cleaned_review
# 0  margot best she given film disappoint market f...
# 1  make barbi greta gerwig singlehandedli direct ...
# 2  qualiti humor write movi fun quirki uniqu get ...
# 3  much pain give movi call barbi brilliantli han...
# 4  woman grew barbi excit movi curiou see would e...

# %%
df.to_csv('barbie_cleaned_reviews.csv', index=False)
df.head()
# Out:
#                                       review_title  \
# 0                   Beautiful film, but so preachy
# 1                                  A Hot Pink Mess
# 2  Could Have Been Great. 2nd Half Brings It Down.
# 3  As a guy I felt some discomfort, and that's ok.
# 4                                 Too heavy handed
#
#                                          review_text rating  \
# 0  Margot does the best with what she's given, bu...      6
# 1  Before making Barbie (2023), Greta Gerwig sing...      6
# 2  The quality, the humor, and the writing of the...      6
# 3  As much as it pains me to give a movie called ...     10
# 4  As a woman that grew up with Barbie, I was ver...      6
#
#                                        noise_removed  \
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie 2023 Greta Gerwig singleh...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...
#
#                                      numbers_removed  \
# 0  Margot does the best with what shes given but ...
# 1  Before making Barbie  Greta Gerwig singlehande...
# 2  The quality the humor and the writing of the m...
# 3  As much as it pains me to give a movie called ...
# 4  As a woman that grew up with Barbie I was very...
#
#                                           lowercased  \
# 0  margot does the best with what shes given but ...
# 1  before making barbie  greta gerwig singlehande...
# 2  the quality the humor and the writing of the m...
# 3  as much as it pains me to give a movie called ...
# 4  as a woman that grew up with barbie i was very...
#
#                                    stopwords_removed  \
# 0  margot best shes given film disappointing mark...
# 1  making barbie greta gerwig singlehandedly dire...
# 2  quality humor writing movie fun quirky unique ...
# 3  much pains give movie called barbie brilliantl...
# 4  woman grew barbie excited movie curious see wo...
#
#                                              stemmed  \
# 0  margot best she given film disappoint market f...
# 1  make barbi greta gerwig singlehandedli direct ...
# 2  qualiti humor write movi fun quirki uniqu get ...
# 3  much pain give movi call barbi brilliantli han...
# 4  woman grew barbi excit movi curiou see would e...
#
#                                           lemmatized  \
# 0  margot best she given film disappoint market f...
# 1  make barbi greta gerwig singlehandedli direct ...
# 2  qualiti humor write movi fun quirki uniqu get ...
# 3  much pain give movi call barbi brilliantli han...
# 4  woman grew barbi excit movi curiou see would e...
#
#                                       cleaned_review
# 0  margot best she given film disappoint market f...
# 1  make barbi greta gerwig singlehandedli direct ...
# 2  qualiti humor write movi fun quirki uniqu get ...
# 3  much pain give movi call barbi brilliantli han...
# 4  woman grew barbi excit movi curiou see would e...

# %% [markdown]
# # Question 3 (30 points)
#
# Write a python program to **conduct syntax and structure analysis of the clean text** you just saved above. The syntax and structure analysis includes:
#
# (1) **Parts of Speech (POS) Tagging:** Tag Parts of Speech of each word in the text, and calculate the total number of N(oun), V(erb), Adj(ective), Adv(erb), respectively.
#
# (2) **Constituency Parsing and Dependency Parsing:** print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) **Named Entity Recognition:** Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
# Your code here

# !pip install nltk
# !python -m nltk.downloader averaged_perceptron_tagger
# Out:
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)
# /usr/lib/python3.10/runpy.py:126: RuntimeWarning: 'nltk.downloader' found in sys.modules after import of package 'nltk', but prior to execution of 'nltk.downloader'; this may result in unpredictable behaviour
#   warn(RuntimeWarning(msg))
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
import nltk
nltk.download('punkt')
nltk.download('words')
nltk.download('maxent_ne_chunker')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package words to /root/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# True

# %%
import pandas as pd
import spacy
import nltk
from nltk import pos_tag, ne_chunk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tree import Tree
from collections import Counter

# Load the spaCy English model for dependency parsing and named entity recognition.
nlp = spacy.load("en_core_web_sm")

# Function to print constituency parsing tree using NLTK.
def print_constituency_tree(text):
    """Prints the constituency parsing tree of a text using NLTK."""
    sentences = nltk.sent_tokenize(text)
    for sentence in sentences:
        words = nltk.word_tokenize(sentence)
        tagged = pos_tag(words)
        chunked = ne_chunk(tagged)
        for subtree in chunked:
            if type(subtree) == Tree:
                print(subtree.label(), " ".join(word for word, pos in subtree.leaves()))
            else:
                print(subtree[0], subtree[1])

# Function to print dependency parsing tree using spaCy.
def print_dependency_tree(text):
    """Prints the dependency parsing tree of a text using spaCy."""
    doc = nlp(text)
    for token in doc:
        print(f"{token.text} --> {token.dep_} --> {token.head.text}, children: {[child for child in token.children]}")

# Function to extract named entities and count their occurrences.
def extract_named_entities(text):
    """Extracts named entities from the text and counts their occurrences."""
    doc = nlp(text)
    entity_counter = Counter()
    for ent in doc.ents:
        entity_counter[ent.label_] += 1
    return entity_counter

# Load the cleaned text from the CSV file, focusing on the first 50 rows.
df = pd.read_csv("barbie_cleaned_reviews.csv", nrows=50)

# Combine the cleaned text from these rows into a single string for analysis.
combined_text = " ".join(df['cleaned_review'].tolist())

# (1) POS Tagging
tokens = word_tokenize(combined_text)
pos_tags = pos_tag(tokens)
noun_count = len([word for word, pos in pos_tags if pos.startswith('N')])
verb_count = len([word for word, pos in pos_tags if pos.startswith('V')])
adj_count = len([word for word, pos in pos_tags if pos.startswith('J')])
adv_count = len([word for word, pos in pos_tags if pos.startswith('R')])

print(f"Total Nouns: {noun_count}")
print(f"Total Verbs: {verb_count}")
print(f"Total Adjectives: {adj_count}")
print(f"Total Adverbs: {adv_count}")

# (2) Constituency Parsing and Dependency Parsing
print("Constituency Parsing Trees:")
print_constituency_tree(combined_text)
print("\nDependency Parsing Tree:")
print_dependency_tree(combined_text)

# (3) Named Entity Recognition
entity_counter = extract_named_entities(combined_text)
print("Named Entities:")
for entity, count in entity_counter.items():
    print(f"{entity}: {count}")
# Out:
# Streaming output truncated to the last 5000 lines.
# joke VBD
# wonder JJR
# feel NN
# good JJ
# vibe NN
# thought VBD
# would MD
# much RB
# differ VB
# end NN
# made VBN
# feel NN
# sad JJ
# empti NN
# ken VBN
# barbi NN
# dont JJ
# end NN
# togeth NN
# made VBD
# ken JJ
# seem VBP
# like IN
# complet NN
# idiot VBP
# actual JJ
# present JJ
# men NNS
# dumb VBP
# throughout IN
# whole JJ
# movi NN
# im NN
# man NN
# that WDT
# true JJ
# depress NN
# sad JJ
# never RB
# way NN
# barbi JJ
# creat NN
# know VBP
# lot NN
# peopl JJ
# wont NN
# agre NN
# that WDT
# okay VBZ
# pointless NN
# go VB
# see RB
# good JJ
# thing NN
# barbi NN
# aesthet NN
# beauti NN
# donei NNS
# like IN
# way NN
# present JJ
# men NNS
# almost RB
# like IN
# want VBP
# woman NN
# turn VB
# men NNS
# case NN
# point NN
# movi NN
# degrad NN
# mani NN
# peopl NN
# dont NN
# know VBP
# put VBN
# spoiler JJ
# super NN
# worn NN
# haha NN
# put VBD
# didi RP
# clue JJ
# movi NN
# like IN
# seem VBP
# like IN
# strang NN
# differ VBP
# type NN
# movi NN
# go VBP
# kind NN
# movi NN
# kid NN
# tell NN
# everyth NN
# perfect VBP
# noth DT
# like IN
# thatther NN
# coupl NN
# young JJ
# teen JJ
# girl NN
# right JJ
# mom NN
# felt VBD
# weird JJ
# know JJ
# way NN
# would MD
# bring VB
# kid NN
# teen JJ
# see VBP
# thisth JJ
# movi FW
# realli JJ
# focus NN
# polit NN
# gender NN
# view NN
# one CD
# total NN
# surpris NN
# mether PRP
# point NN
# kind NN
# roll NN
# eye NN
# bit NN
# sing JJ
# kind NN
# went VBD
# also RB
# time NN
# tearyther CC
# sexual JJ
# refer NN
# young JJ
# kid NN
# would MD
# understand VB
# one CD
# part NN
# tell VB
# specif JJ
# thing NN
# specif JJ
# thing NN
# ken VBN
# bit NN
# strangeth JJ
# end NN
# threw VBD
# movi JJ
# seem NNS
# say VBP
# equal JJ
# treat NN
# way NN
# yet RB
# time NN
# seem JJ
# make VBP
# men NNS
# mindless VB
# idiot NN
# also RB
# someth VBZ
# one CD
# male NN
# charact NN
# ask JJ
# end NN
# repli NN
# woman NN
# give VB
# seem JJ
# lead JJ
# one CD
# believ JJ
# thing NN
# exact JJ
# unlik JJ
# way NN
# thing NN
# seem VBP
# barbi JJ
# land NN
# woman NN
# men NNS
# didnt VBP
# realli JJ
# get NN
# may MD
# last JJ
# line NN
# movi VBD
# place NN
# barbi NN
# somewher NN
# didnt NN
# get VB
# point NN
# iti RB
# heard VBD
# adult NN
# laugh IN
# repeatedli NN
# kid NN
# kind NN
# sat VBD
# silentthi JJ
# one CD
# movi NN
# can MD
# not RB
# see VB
# everi JJ
# watch NN
# fun NN
# uniqu JJ
# see NN
# theater NN
# also RB
# dug VBZ
# set VBN
# design NN
# stuff NN
# barbi NN
# world NN
# cool NN
# see VBP
# went VBD
# see VB
# today NN
# everyon VB
# group NN
# dress NN
# pink VBP
# readi NN
# least JJS
# entertain JJ
# pastelcolor NN
# camp NN
# two CD
# hour NN
# barbi NN
# kind NN
# succe NN
# love NN
# costum NN
# set VBN
# barbieland NN
# margot VBD
# robi JJ
# fantast NN
# actress NN
# perfect JJ
# embodi JJ
# optimist NN
# shecandoital JJ
# barbi NN
# ryan NN
# gosl NN
# scenesteal NN
# hors NNS
# ob VBP
# faux JJ
# mink NN
# coatdespit NN
# movi JJ
# whole JJ
# disappoint NN
# much JJ
# succe NN
# campi NN
# comedi NN
# music NN
# number NN
# attempt JJ
# feminist JJ
# commentari NN
# existenti VBP
# fall NN
# flat JJ
# messag NN
# nose RB
# spell RB
# right JJ
# audienc NN
# one CD
# strain NN
# brain NN
# scene NN
# cant JJ
# funni NN
# hit VBD
# home NN
# guitar NN
# gag NN
# gave VBD
# colleg JJ
# flashback NN
# littl NN
# subtleti NN
# could MD
# hurti VB
# also RB
# issu JJ
# differ NN
# barbieland NN
# real JJ
# world NN
# accept NN
# everyon NN
# barbieland NN
# talk NN
# mani JJ
# term NN
# marvel NN
# speak JJ
# youv NN
# watch NN
# anyth NN
# made VBD
# past JJ
# year NN
# youll NN
# recogn NN
# right RB
# away RB
# know VBP
# make VBP
# pop JJ
# cultur NN
# refer NN
# like IN
# spiderman JJ
# mcu JJ
# alien NNS
# say VBP
# think VBP
# bluntest JJS
# way NN
# possibl JJ
# awkward RB
# funni JJ
# oooor NN
# novel RB
# new JJ
# year NN
# ago RB
# staler VBD
# pepsi NNS
# clear JJ
# oh IN
# yeah NN
# rememb NN
# macarenath NN
# barbi NN
# ken VBN
# suppos JJ
# simplist NN
# figur NN
# sen NN
# emot NN
# nuanc NN
# howev NN
# human JJ
# real JJ
# world NN
# suppos NN
# opposit NN
# messi VBZ
# complic JJ
# charm NN
# also RB
# talk VBP
# like IN
# feel NN
# lazyand NN
# existenti VBP
# theme NN
# margot VBD
# robi JJ
# barbi NN
# get VB
# tire JJ
# ideal JJ
# independ NN
# womanhood NN
# etern JJ
# paradis JJ
# end NN
# choos NN
# human JJ
# embrac NN
# mortal JJ
# mortal JJ
# ultim JJ
# give JJ
# live JJ
# mean NN
# decent JJ
# theme NN
# bad JJ
# movi NN
# never RB
# realli VBZ
# delv JJ
# given VBN
# lip NN
# servic NN
# noth DT
# moreit FW
# cute JJ
# moment NN
# honestli JJ
# end NN
# experi NN
# meh NN
# hype NN
# memor NN
# finish JJ
# product NN
# im NN
# sure JJ
# first JJ
# movi NN
# kept VBD
# get VB
# even RB
# fun NN
# entertain VBP
# definit NN
# better RBR
# also RB
# surprisingli JJ
# deal NN
# legit JJ
# seriou NN
# stuff NN
# barbi NN
# weirdli NN
# fun NN
# movi NN
# fill JJ
# interest NN
# concept NN
# definit NN
# first JJ
# time NN
# that WDT
# ever RB
# done VBN
# greta NN
# gerwig NN
# creat NN
# whole JJ
# new JJ
# style NN
# filmmak NN
# specif NN
# barbi NN
# intent NN
# weird NN
# yet RB
# creativ JJ
# edit NN
# awkward RB
# cring VBG
# scene NN
# found VBD
# comedi RB
# funni JJ
# instead RB
# cring VBG
# barbi IN
# one CD
# origin NN
# movi NN
# year NN
# also RB
# one CD
# origin NN
# movi RBS
# ive JJ
# seen VBN
# know VBP
# margot JJ
# robbi JJ
# ryan NN
# gosl NN
# gon NN
# na TO
# carri VB
# movi JJ
# ferrel NN
# simu NN
# liu JJ
# whole JJ
# rest NN
# cast NN
# also RB
# great JJ
# entertain JJ
# soundtrack NN
# great JJ
# except IN
# nicki JJ
# minaj NN
# ice NN
# spice NN
# barbi NN
# world NN
# song NN
# absolut NN
# terribl NN
# billi NN
# eilish JJ
# made VBN
# tune NN
# kept VBD
# haunt NN
# background NN
# final JJ
# get NN
# perfect JJ
# scene NN
# play NN
# realli VBZ
# best RBS
# thing NN
# song NN
# beauti NN
# emot NN
# anyway RB
# barbi JJ
# lot NN
# fun NN
# still RB
# notic JJ
# flaw NN
# found VBD
# funni RB
# entertain JJ
# colour NN
# creativ NN
# fun NN
# pure NN
# fun NN
# someth VBZ
# probabl VBP
# love VB
# even RB
# second JJ
# time NN
# see VB
# right JJ
# barbi VB
# good JJ
# time NN
# definit JJ
# recommend NN
# movi NN
# somehow VBP
# actual JJ
# possibl NN
# liveact NN
# barbi NN
# movi NNS
# need VBP
# good JJ
# writer NN
# good JJ
# director NN
# good JJ
# cast NN
# deliv NN
# mostli NN
# greta NN
# gerwig NN
# noah JJ
# baumbach NN
# knack NN
# incorpor NN
# mani NN
# littl NN
# observ JJ
# life NN
# whether IN
# funni JJ
# deepli NN
# interperson NN
# screenplay NN
# gerwig NN
# manag NN
# direct JJ
# great JJ
# visual JJ
# clever NN
# transitionsunfortun NN
# major JJ
# weak JJ
# film NN
# opinion NN
# also RB
# lie JJ
# screenplay NN
# deal NN
# larger JJR
# societ JJ
# issu NN
# lack NN
# depth NN
# possibl NN
# understand VBP
# observ JJ
# work NN
# contextu NN
# fall NN
# short JJ
# approach NN
# feel VB
# crude JJ
# superfici JJ
# creat NN
# confus JJ
# overal JJ
# impress NN
# fine NN
# craft NN
# small JJ
# observ NN
# remain VBP
# convinc JJ
# film NN
# intellig NN
# funni NN
# creativ NN
# individu JJ
# level NN
# suddenli NN
# seem VBP
# foolish JJ
# grand JJ
# scheme NN
# thingskey JJ
# moment NN
# film NN
# encount NN
# inventor NN
# fail VBP
# evok NN
# emot NN
# come VBN
# across IN
# insincer NN
# angri NN
# rant NN
# struggl NN
# woman NN
# feel VB
# cheap JJ
# seem VBP
# lack JJ
# sensit NN
# someon NN
# want VBP
# vent NN
# without IN
# make NN
# effort NN
# packag NN
# intelligentlyani JJ
# scene NN
# trigger NN
# sen VBN
# injustic JJ
# express NN
# societ JJ
# critic JJ
# small JJ
# moment NN
# longer RBR
# feel VB
# precis NN
# may MD
# even RB
# intent VB
# appear JJ
# exagger NN
# rather RB
# convinc JJ
# part NN
# larger JJR
# wholeoveral JJ
# im NN
# entir JJ
# sure JJ
# make NN
# film NN
# one CD
# hand NN
# great JJ
# time NN
# hand NN
# left VBD
# screen JJ
# mix NN
# feelingsmak VBD
# even RB
# confus JJ
# consist NN
# brilliant JJ
# act NN
# perform NN
# across IN
# board NN
# ryan NN
# gosl VBP
# obvious JJ
# stand VBP
# year NN
# old JJ
# daughter NN
# wrote VBD
# follow JJ
# review NN
# post NN
# imdb NN
# accounta NN
# barbi NN
# fan NN
# excit JJ
# movi NN
# expect VBP
# lightheart NN
# goofi NN
# comedi NN
# instead RB
# got VBD
# movi JJ
# felt VBD
# though IN
# didnt NN
# know VBP
# go VB
# doingth JJ
# movi JJ
# start NN
# fun NN
# goofi NN
# comedi JJ
# thing NN
# start NN
# changingth VB
# start NN
# go VB
# wrong JJ
# barbi RB
# go VBP
# real JJ
# world NN
# fix NN
# suppos NN
# help NN
# person NN
# play VB
# fix NN
# problem NN
# barbi NN
# land NN
# wouldv WRB
# enough JJ
# movi NN
# keep VB
# goinginstead NN
# go VB
# depth JJ
# life NN
# mother NN
# caus NN
# problem NN
# barbi NN
# movi NN
# goe NN
# total JJ
# differ NN
# directionken NN
# see VBP
# real JJ
# world NN
# patriarchi NN
# goe VBP
# back RB
# barbi JJ
# land NN
# replic NN
# barbi NN
# go VBP
# back RB
# barbi JJ
# land NN
# save VBP
# new JJ
# patriarchybi JJ
# end NN
# movi NN
# barbi NN
# decid NN
# live JJ
# real JJ
# world NN
# ken VBN
# barbi JJ
# land NN
# basic JJ
# back RB
# littl JJ
# power NN
# upris JJ
# find VBP
# treatment NN
# ken JJ
# end NN
# hypocrit NN
# compar NN
# movi NN
# suppos NN
# messag NN
# equalitythi NN
# movi NN
# write NN
# plot NN
# bad JJ
# even RB
# feminist VBP
# acknowledg JJ
# messag NN
# terribl NN
# preachi NN
# feel VB
# though IN
# mani JJ
# differ NN
# plot NN
# idea NN
# couldv NN
# good JJ
# confus NN
# togetheron NN
# good JJ
# note NN
# act NN
# set VBN
# movi JJ
# realli NN
# good JJ
# love NN
# see VBP
# plastic JJ
# barbi NN
# hous JJ
# life NN
# movi NN
# also RB
# funni JJ
# part NN
# wish JJ
# movi NN
# pick NN
# clearer NN
# direct JJ
# honestli NN
# doubt NN
# movi NN
# first RB
# surprisingli JJ
# find VBP
# realli JJ
# like IN
# quit NN
# lotset VBP
# color NN
# barbi NN
# land NN
# stereotyp NN
# barbi NN
# live VBP
# perfect JJ
# life NN
# everi JJ
# singl JJ
# day NN
# one CD
# day NN
# show VB
# sign JJ
# beinga JJ
# human JJ
# decid NN
# go VB
# real JJ
# world NN
# find VBP
# cure NN
# order NN
# make VBP
# perfect JJ
# againbarbi NN
# fun NN
# movi NN
# surprisingli NN
# plenti NN
# heartwarm NN
# moment NN
# good JJ
# messag NN
# offer NN
# set VBN
# design NN
# eyecatch NN
# point NN
# well RB
# margot VBD
# robbi JJ
# ryan JJ
# gosl NN
# nail JJ
# part NN
# gosl NN
# mostli NN
# shinessometh VBZ
# im JJ
# pretti JJ
# sure JJ
# movi NN
# get NN
# nomin JJ
# oscar NN
# like IN
# best JJS
# product NN
# design NN
# best JJS
# costum NN
# design NN
# probabl NN
# best JJS
# song NN
# billi NN
# eilish NN
# song NN
# beauti NN
# stuck VBN
# head NN
# right NN
# walk VBP
# theatr IN
# think NN
# yeah RB
# good JJ
# time NN
# movi NNS
# day NN
# went VBD
# kind NN
# ok NN
# kebab NN
# probabl NN
# wasnt VBD
# good JJ
# ideath NN
# film NN
# stun JJ
# product NN
# design NN
# creativ NN
# margot VBD
# robbi JJ
# perfectli NN
# cast VBD
# stereotyp JJ
# barbi IN
# part NN
# song NN
# catchi NN
# perform NN
# solid JJ
# type NN
# charact NN
# portrayingwhen NN
# strip VBZ
# away RB
# outsid JJ
# world NN
# messag NN
# barbi NN
# ken VBN
# poignant JJ
# moment NN
# barbi NN
# realis NN
# she PRP
# perfect VBZ
# she PRP
# made VBD
# believ NN
# ken VB
# receiv NN
# first RB
# modicum VBZ
# acknowledg JJ
# sentient NN
# he PRP
# ever RB
# life NN
# also RB
# share NN
# coupl NN
# learn NN
# growth NN
# moment NN
# thought VBN
# would MD
# pay VB
# end VB
# filmi JJ
# dont NN
# know VBP
# hope NN
# someth NNS
# would MD
# actual JJ
# enlighten VB
# audienc JJ
# acknowledg JJ
# thing NN
# mess NN
# make VBP
# intent NN
# meaning VBG
# step NN
# get VB
# u JJ
# closer JJR
# understand JJ
# equal JJ
# barbi NN
# brand NN
# histori NN
# controversi NN
# engrain VBP
# cultur JJ
# movi NN
# potenti NN
# chang NN
# perspect JJ
# world NN
# futur NN
# could MD
# that WDT
# lot VBD
# pressur IN
# one CD
# film NN
# knowhowev NN
# film NN
# absolut NN
# immun NN
# notsosubtl JJ
# messag NN
# permeat NN
# form NN
# medium NN
# entertain VBP
# recent JJ
# fact NN
# embrac RB
# much JJ
# scene NN
# man NN
# walk VBP
# behind IN
# barbi NN
# slap NN
# backsid NN
# broad JJ
# daylight NN
# crowd NN
# space NN
# front JJ
# boyfriend NN
# kind NN
# portray JJ
# men NNS
# appear VBP
# film NN
# view NN
# worldmayb VBP
# kind NN
# overt JJ
# comic JJ
# depict NN
# men NNS
# world NN
# gener NN
# allow VBP
# get VB
# movi JJ
# kind NN
# enjoy NN
# upon IN
# reflect NN
# realis NN
# kind NN
# yuckbarbi NN
# rare JJ
# opportun NN
# film NN
# experi NN
# highlight VBD
# issu JJ
# real JJ
# world NN
# offer VBP
# foster JJ
# idea NN
# chang NN
# instead RB
# receiv JJ
# divis NN
# meanspirit NN
# attack NN
# half NN
# human JJ
# popul NN
# well RB
# anyon RB
# think VBP
# famili JJ
# accept IN
# path JJ
# life NN
# also RB
# flat JJ
# foot NN
# celluliteif NN
# kind NN
# switch NN
# brain NN
# hour NN
# bit NN
# dont JJ
# take NN
# film NN
# serious JJ
# mayb NN
# youll NN
# last JJ
# posit NN
# memori VBD
# see VBP
# moviebut NNS
# need VBP
# enjoy VBP
# someth NNS
# need VBP
# ask RB
# usual JJ
# write NN
# review NN
# beyond IN
# descript NN
# last JJ
# time NN
# wrote VBD
# review NN
# absolut NN
# horribl NN
# wrinkl NN
# time NN
# almost RB
# bad JJ
# least JJS
# gosl JJ
# play NN
# part NN
# well RB
# stori JJ
# abysm NNS
# find VBP
# anyth JJ
# el NNS
# like IN
# watch NN
# paint NN
# dri NN
# ye PRP
# plea VBP
# save JJ
# brain NN
# cell NN
# agoni RB
# pain RB
# slow JJ
# nearli NN
# two CD
# hour NN
# long RB
# mindnumb JJ
# storytel NN
# mediocr NN
# worst JJS
# mani JJ
# way NN
# say VBP
# go VBP
# see JJ
# choic NN
# see VB
# anyth JJ
# el FW
# exercis JJ
# horrend NN
# clich NN
# exagger NN
# selfimport NN
# could MD
# give VB
# neg JJ
# star NN
# would MD
# wow VB
# movi JJ
# love NN
# letter NN
# cinema NN
# kubrick NN
# refer NN
# open JJ
# soundstag NN
# real JJ
# cgi NN
# set VBN
# danc NN
# sequenc NN
# like IN
# olden JJ
# day NN
# think VBP
# greas NNS
# costum VBP
# wow JJ
# costum NN
# greta NN
# gerwig NN
# dug NN
# deep JJ
# make NN
# masterpiec NN
# use NN
# technic JJ
# chop NN
# along IN
# way NN
# cast NN
# director NN
# also RB
# nail JJ
# everyon NN
# wonderfulth NN
# act NN
# perfect JJ
# love NN
# see NN
# varieti JJ
# barbi NN
# screen NN
# mani NN
# joke NN
# would MD
# appropri VB
# audienc JJ
# voluntari JJ
# pg NN
# rate NN
# wasnt NN
# swear VBP
# nuditi IN
# one CD
# beach NN
# fight NN
# amongst NN
# ken VBD
# that IN
# realli NN
# violenc NN
# compar NN
# today NN
# averag VBP
# film NN
# one CD
# harm NN
# fake NN
# blood NN
# usedi JJ
# actual JJ
# didnt NN
# like IN
# end NN
# quit NN
# annoy VBZ
# rhea JJ
# perlman JJ
# play NN
# creator NN
# barbi NN
# made VBD
# two CD
# quip NNS
# ir VBP
# get VB
# tax NN
# evas NN
# someth NN
# ruth NN
# handler NN
# never RB
# dealt VBD
# problem NN
# sec NN
# sign NN
# posit NN
# mattel NN
# earn VBP
# forecast VBN
# knew JJ
# quarter NN
# how WRB
# tough JJ
# explainirregardless NN
# want VBP
# see NN
# movi JJ
# watch NN
# wife NN
# readi NN
# turn VBP
# ten VBN
# minut JJ
# talk NN
# watch NN
# itll NN
# get VB
# better JJR
# honey NN
# theyll NN
# go VBP
# real JJ
# world NN
# soonwel NN
# didnt NN
# get VBP
# better RBR
# went VBD
# real JJ
# world NN
# feel VBP
# like IN
# better JJR
# show NN
# barbieland NN
# seem VBP
# realisticther RB
# isnt JJ
# anyth NN
# wrong JJ
# act JJ
# product NN
# script NN
# weak JJ
# particularli NN
# get VB
# real JJ
# world NN
# peopl NN
# dont VBP
# act NN
# like IN
# im JJ
# disappoint NN
# actor NN
# think VBP
# thought VBN
# would MD
# great JJ
# movi VB
# howev RB
# much JJ
# letdown IN
# movi RB
# much JJ
# fun NN
# start NN
# realli NN
# strong JJ
# although IN
# stori JJ
# move VB
# away RB
# barbieland NN
# sooner RB
# would MD
# like VB
# nonetheless RB
# regain JJ
# foot JJ
# final JJ
# act NN
# particular NN
# could MD
# stop VB
# laugh NN
# ryan JJ
# gosl NN
# portray NN
# ken NN
# song NN
# forev JJ
# stuck NN
# headther NN
# also RB
# plenti RB
# good JJ
# messag NN
# taken VBN
# away RB
# experi JJ
# your PRP$
# insecur JJ
# middleag JJ
# male NN
# terrifi NN
# woman NN
# love VB
# everyth NN
# movi NNS
# say VBP
# patriarchi JJ
# barbi NN
# grow VB
# consumer NN
# much JJ
# morei NN
# excit NN
# watch NN
# soon RB
# pace NN
# perfect JJ
# huge JJ
# potenti NN
# fulli NNS
# match VBP
# pure NN
# cinemat NN
# experi VBP
# never RB
# forget VB
# movi JJ
# movi JJ
# way NN
# overhyp IN
# everyon JJ
# kept NNS
# say VBP
# amaz JJ
# final JJ
# go NN
# watch NN
# thought VBD
# go VB
# storylin JJ
# good JJ
# basic JJ
# corni NN
# storylin NN
# opinioni NN
# didnt NN
# care NN
# portray NN
# ken VBD
# ryan JJ
# gosl NN
# amaz NN
# actor NN
# good JJ
# represent NN
# ken VBN
# come JJ
# look VBP
# actual JJ
# ken NNP
# doll NN
# look NN
# way NN
# act NN
# ken VB
# good JJ
# either CC
# didnt JJ
# get NN
# much JJ
# help NN
# writer VB
# way NN
# wrote VBD
# part NN
# movi NN
# much JJ
# potenti NN
# definit NN
# let VBD
# one CD
# posit NN
# funni JJ
# part NN
# could MD
# written VBN
# much RB
# better RBR
# could MD
# much RB
# better RBR
# storylin NN
# margot VBD
# robbi JJ
# ryan JJ
# gosl NN
# realli NN
# great JJ
# role NN
# barbi NN
# kent NN
# gosl NN
# special JJ
# hilari NN
# expect VBP
# funni JJ
# cool JJ
# deep JJ
# entertain NN
# movi NN
# highli NN
# disappoint NN
# movi NN
# terribl NN
# preachi JJ
# end NN
# embarrass NN
# audienc NN
# brain NN
# plea NN
# preach NN
# somewher NN
# el NN
# furthermor NN
# movi NN
# divid NN
# unit NN
# im JJ
# woman NN
# script NN
# movi NN
# horrend VBP
# direct JJ
# plain NN
# bad JJ
# great JJ
# actress NN
# littl NNS
# say VBP
# like IN
# emma NN
# mackey NN
# that WDT
# piti VBZ
# overal JJ
# huge JJ
# disappoint NN
# miss NNS
# opportun VBP
# point NN
# margot VBD
# robbi JJ
# point NN
# ryan NN
# gosl NN
# point NN
# art NN
# direct JJ
# super NN
# tacki NN
# pinki NN
# barbi NN
# world NN
# wow NN
# see VBP
# masterpiec JJ
# come VBP
# that IN
# joke NN
# somehow RB
# greta JJ
# gerwig NN
# took VBD
# barbi NN
# made VBN
# movi NN
# tackl NN
# realli VBP
# tough JJ
# social JJ
# issueswel NN
# crazi NN
# wow NN
# work NN
# stori NN
# matur NN
# thinker NN
# plot NN
# your PRP$
# done VBN
# laugh NN
# butt NN
# youll NN
# get NN
# realli JJ
# emot JJ
# product NN
# design NN
# point NN
# whole JJ
# movi NN
# pink NN
# everyth VBP
# never RB
# polar JJ
# shade NN
# melt VBD
# togeth JJ
# plea NN
# way NN
# cours NNS
# cast VBD
# margot JJ
# robbi NN
# born VBN
# play VBP
# barbi NN
# hit VBD
# home NN
# run NN
# ryan JJ
# gosl NN
# dude NN
# rock NN
# ken VBD
# knock JJ
# way NN
# around IN
# world NN
# hit VBD
# back RB
# head JJ
# steal NN
# everi JJ
# scene NN
# he PRP
# would MD
# board NN
# ken VB
# spinoff NN
# america NN
# ferrara NN
# simu NN
# liu NN
# also RB
# great JJ
# respect JJ
# role NN
# cast VBD
# overal JJ
# perfect JJ
# overal JJ
# barbi NN
# probabl NN
# best JJS
# movi NN
# base NN
# toy NN
# sorri NN
# lego NN
# movi JJ
# overal JJ
# fantast NN
# time NN
# movi JJ
# mr NN
# shullivan NN
# enjoy NN
# first RB
# minut CC
# full JJ
# length NN
# featur NN
# film NN
# third JJ
# song NN
# danc NN
# number NN
# variou NN
# ken VBN
# agre JJ
# ryan JJ
# gosl NN
# appear VBP
# main JJ
# charact NN
# barbiedont NN
# get VBP
# wrong JJ
# ryan JJ
# gosl NN
# margot VBD
# robbi JJ
# perform NN
# respect NN
# doll NN
# like IN
# roll NN
# ken VBN
# barbi RB
# well RB
# balanc NN
# comed VBD
# realist JJ
# deliveri NN
# produc NN
# appear VBP
# display NN
# ryan JJ
# gosl NN
# ken VBN
# doll NN
# enhanc NN
# cgi NN
# eight CD
# pack NN
# abdomen NNS
# bulg VBP
# bicep JJ
# thought NN
# vaniti NN
# project NN
# ryan VBZ
# gosl VBP
# rather RB
# opportun JJ
# reflect VB
# chang JJ
# world NN
# advanc NN
# femin NN
# barbi NN
# vision NN
# chang NN
# worldth VBP
# visual JJ
# multi NN
# color NN
# pastel NN
# remind NN
# elvi NN
# film NN
# blue JJ
# hawaii NN
# sinc NN
# barbi NN
# elvi VBP
# popular JJ
# icon NN
# within IN
# era NN
# downsid NN
# barbi NN
# film NN
# messag FW
# person NN
# reliant JJ
# man NN
# seem VBP
# get VB
# lost VBN
# multipl NN
# song NN
# danc NN
# number NN
# provid JJ
# ensembl JJ
# cast NN
# male NN
# ken VBN
# dollsal JJ
# decent JJ
# film NN
# consid NN
# futur NN
# film NN
# classic JJ
# memor NN
# ryan NN
# goslng NN
# margot VBD
# robbi JJ
# perform NN
# worthi NN
# academi RB
# award RB
# like IN
# barbi NN
# may MD
# rememb VB
# today NN
# memor FW
# place NN
# time NN
# long JJ
# past NN
# era NN
# would MD
# surpris VB
# see VB
# tv JJ
# produc NN
# turn NN
# barbi NN
# film NN
# franchis NN
# merchandis NN
# bonanza NN
# weekli NN
# minut JJ
# tv NN
# sitcom NN
# humbl NN
# opinion NN
# could MD
# hold VB
# mr JJ
# shullivan JJ
# attent NN
# fori NNS
# give VBP
# film NN
# decent JJ
# imdb NN
# rate NN
# play NN
# barbi NN
# lot NN
# kid VBD
# thought JJ
# movi NNS
# go VB
# fun RB
# trailer JJ
# look NN
# great JJ
# thought JJ
# let NN
# girl VB
# movi JJ
# night NN
# kick NN
# back RB
# relax JJ
# watch NN
# funni NN
# icon NN
# movi NN
# favorit NN
# toy NN
# kid NN
# greatli NN
# let VBD
# realli VB
# fast JJ
# movi NN
# strong JJ
# messag NN
# woman NN
# man NN
# world NN
# defin NN
# role NN
# whoever WP
# noth DT
# movi NN
# made VBD
# laugh IN
# felt JJ
# kinda NN
# heavi NN
# messag NN
# tell VBP
# definit NN
# kid NN
# movi NN
# either CC
# dont JJ
# think NN
# would MD
# understand VB
# half NN
# realli NN
# wasnt NN
# happi NN
# movi NN
# realli NN
# enjoy NN
# first RB
# minut VBZ
# movi JJ
# upbeat JJ
# posit NN
# light JJ
# howev JJ
# thing NN
# soon RB
# becam VBD
# neg JJ
# minut NN
# movi NN
# couldnt NN
# stand VBP
# barbi JJ
# world NN
# attitud NN
# constant JJ
# bummer NN
# ken VBN
# attitud RB
# sour JJ
# next JJ
# hour NN
# movi NN
# live JJ
# negativityi NN
# bought VBD
# ticket NN
# show VB
# month NN
# ago IN
# saw VBD
# day NN
# offici JJ
# open JJ
# day NN
# excit VB
# movi JJ
# play NN
# music NN
# dua NN
# lipa NN
# song NN
# almost RB
# everi JJ
# day NN
# realli VB
# excit JJ
# movi NNS
# look VBP
# forward RB
# someth JJ
# posit NN
# vast JJ
# major JJ
# movi NNS
# conflict VBP
# part NN
# write VBP
# much JJ
# movi NN
# didnt NN
# need VBP
# go VB
# way NN
# far RB
# fast RB
# would MD
# prefer VB
# shallow JJ
# fun NN
# barbi NN
# movi NN
# v NN
# barbi NN
# movi NN
# fill VB
# hour NN
# conflict NN
#
# Dependency Parsing Tree:
# margot --> advmod --> best, children: []
# best --> advmod --> given, children: [margot]
# she --> nsubj --> given, children: []
# given --> ROOT --> given, children: [best, she, start, end, man]
# film --> compound --> satir, children: []
# disappoint --> compound --> market, children: []
# market --> compound --> fun, children: [disappoint]
# fun --> compound --> satir, children: [market]
# quirki --> compound --> satir, children: []
# satir --> compound --> movi, children: [film, fun, quirki]
# homag --> compound --> movi, children: []
# movi --> nsubj --> start, children: [satir, homag]
# start --> dobj --> given, children: [movi, way]
# way --> advmod --> start, children: []
# end --> conj --> given, children: [make]
# overdramat --> compound --> speech, children: []
# speech --> nsubj --> end, children: [overdramat]
# end --> nsubj --> make, children: [speech]
# clearli --> compound --> tri, children: []
# tri --> nsubj --> make, children: [clearli]
# make --> ccomp --> end, children: [end, tri, feel]
# audienc --> nsubj --> feel, children: []
# feel --> ccomp --> make, children: [audienc, feel]
# someth --> advmod --> left, children: []
# left --> amod --> everyon, children: [someth]
# everyon --> nsubj --> feel, children: [left]
# feel --> ccomp --> feel, children: [everyon, say]
# confus --> nsubj --> say, children: []
# say --> ccomp --> feel, children: [confus, m]
# i --> nsubj --> m, children: []
# m --> ccomp --> say, children: [i]
# crotcheti --> npadvmod --> old, children: []
# old --> amod --> man, children: [crotcheti]
# man --> dobj --> given, children: [old]
# i --> nsubj --> m, children: []
# m --> ROOT --> m, children: [i, woman]
# woman --> attr --> m, children: []
# i --> nsubj --> m, children: []
# m --> ROOT --> m, children: [i]
# pretti --> npadvmod --> sure, children: []
# sure --> nsubj --> expect, children: [pretti, look, fall, make, portray, combin, given]
# i --> nsubj --> m, children: []
# m --> aux --> victim, children: [i]
# movi --> nmod --> target, children: []
# target --> compound --> parent, children: [movi]
# audienc --> npadvmod --> saddest, children: []
# saddest --> amod --> parent, children: [audienc]
# part --> compound --> parent, children: []
# parent --> compound --> theater, children: [target, saddest, part]
# kid --> compound --> theater, children: []
# theater --> compound --> victim, children: [parent, kid]
# victim --> nmod --> movi, children: [m, theater]
# poor --> amod --> kid, children: []
# market --> compound --> kid, children: []
# kid --> compound --> movi, children: [poor, market]
# movi --> nsubj --> look, children: [victim, kid]
# overal --> amod --> humor, children: []
# humor --> compound --> beauti, children: [overal]
# fun --> compound --> occas, children: []
# occas --> compound --> film, children: [fun]
# film --> compound --> beauti, children: [occas]
# beauti --> nsubj --> look, children: [humor, film]
# look --> ccomp --> sure, children: [movi, beauti]
# whole --> amod --> concept, children: []
# concept --> nsubj --> fall, children: [whole]
# fall --> ccomp --> sure, children: [concept, apart]
# apart --> advmod --> fall, children: []
# second --> amod --> half, children: []
# half --> amod --> film, children: [second]
# film --> compound --> parti, children: [half]
# becom --> compound --> parti, children: []
# piti --> compound --> parti, children: []
# parti --> nmod --> woman, children: [film, becom, piti]
# strong --> amod --> woman, children: []
# woman --> nsubj --> make, children: [parti, strong]
# make --> ccomp --> sure, children: [woman, singlehandedli]
# barbi --> compound --> gerwig, children: []
# greta --> compound --> gerwig, children: []
# gerwig --> nsubj --> singlehandedli, children: [barbi, greta]
# singlehandedli --> ccomp --> make, children: [gerwig]
# direct --> amod --> girl, children: []
# two --> nummod --> ladi, children: []
# film --> compound --> ladi, children: []
# ladi --> compound --> littl, children: [two, film]
# bird --> compound --> littl, children: []
# littl --> compound --> woman, children: [ladi, bird]
# woman --> compound --> girl, children: [littl]
# girl --> compound --> precipic, children: [direct, woman]
# precipic --> nsubj --> portray, children: [girl]
# adolesc --> compound --> layer, children: []
# nuanc --> compound --> layer, children: []
# layer --> nsubj --> portray, children: [adolesc, nuanc]
# portray --> ccomp --> sure, children: [precipic, layer, relationship]
# motherdaught --> amod --> relationship, children: []
# relationship --> dobj --> portray, children: [motherdaught]
# combin --> prep --> sure, children: [good]
# imagin --> nmod --> clever, children: []
# visual --> amod --> clever, children: []
# clever --> amod --> good, children: [imagin, visual]
# dialogu --> amod --> good, children: []
# good --> amod --> combin, children: [clever, dialogu]
# given --> prep --> sure, children: [credenti, one]
# credenti --> pobj --> given, children: []
# one --> pobj --> given, children: []
# may --> aux --> expect, children: []
# expect --> ROOT --> expect, children: [sure, may, isntth, excel, mermaid, exist, begin, oz, parallel, show]
# barbi --> compound --> convinc, children: []
# intellig --> compound --> convinc, children: []
# convinc --> nsubj --> amus, children: [barbi, intellig]
# amus --> compound --> pictur, children: [convinc]
# pictur --> nsubj --> isntth, children: [amus]
# well --> advmod --> isntth, children: []
# isntth --> ccomp --> expect, children: [pictur, well, begin]
# fantasi --> compound --> comedi, children: []
# comedi --> nsubj --> begin, children: [fantasi]
# begin --> ccomp --> isntth, children: [comedi, play]
# barbi --> compound --> barbi, children: []
# land --> compound --> place, children: []
# place --> compound --> barbi, children: [land]
# barbi --> nsubj --> play, children: [barbi, place]
# play --> ccomp --> begin, children: [barbi, margot, robbi, day]
# margot --> dobj --> play, children: []
# robbi --> dobj --> play, children: []
# best --> amod --> day, children: []
# day --> npadvmod --> play, children: [best]
# everi --> amod --> day, children: []
# day --> nmod --> occasion, children: [everi]
# compani --> compound --> barbi, children: []
# barbi --> compound --> occasion, children: [compani]
# occasion --> compound --> cinematographi, children: [day, barbi]
# ken --> compound --> costum, children: []
# design --> compound --> costum, children: []
# costum --> compound --> cinematographi, children: [ken, design]
# cinematographi --> nsubj --> excel, children: [occasion, costum]
# excel --> conj --> expect, children: [cinematographi, vision]
# job --> nmod --> vision, children: []
# recreat --> compound --> mattel, children: []
# mattel --> compound --> vision, children: [recreat]
# vision --> dobj --> excel, children: [job, mattel]
# pink --> amod --> introduct, children: []
# plastic --> nmod --> introduct, children: []
# perfect --> amod --> introduct, children: []
# introduct --> nsubj --> selfawar, children: [pink, plastic, perfect]
# referenti --> compound --> extern, children: []
# overtli --> compound --> reliant, children: []
# reliant --> compound --> extern, children: [overtli]
# extern --> amod --> smartli, children: [referenti, reliant]
# film --> compound --> smartli, children: []
# smartli --> nsubj --> selfawar, children: [extern, film]
# selfawar --> nmod --> lawyer, children: [introduct, smartli, barbi]
# present --> amod --> barbi, children: []
# world --> compound --> barbi, children: []
# barbi --> dobj --> selfawar, children: [present, world]
# anyth --> nmod --> lawyer, children: []
# presid --> amod --> lawyer, children: []
# physicist --> compound --> journalist, children: []
# journalist --> compound --> lawyer, children: [physicist]
# lawyer --> nsubj --> mermaid, children: [selfawar, anyth, presid, journalist]
# mermaid --> ccomp --> expect, children: [lawyer, like, come]
# much --> advmod --> like, children: []
# like --> prep --> mermaid, children: [much, gosl]
# origin --> compound --> toy, children: []
# toy --> compound --> gosl, children: [origin]
# ken --> compound --> gosl, children: []
# ryan --> compound --> gosl, children: []
# gosl --> pobj --> like, children: [toy, ken, ryan]
# come --> xcomp --> mermaid, children: [afterthought]
# afterthought --> npadvmod --> come, children: []
# exist --> ccomp --> expect, children: [within]
# within --> prep --> exist, children: [barbi]
# warmth --> compound --> barbi, children: []
# barbi --> compound --> barbi, children: [warmth]
# gazeth --> compound --> plot, children: []
# plot --> compound --> set, children: [gazeth]
# set --> compound --> barbi, children: [plot]
# motion --> compound --> barbi, children: []
# barbi --> pobj --> within, children: [barbi, set, motion]
# begin --> ccomp --> expect, children: [thought]
# thought --> xcomp --> begin, children: [feel]
# death --> nmod --> foot, children: []
# normal --> amod --> foot, children: []
# suspend --> compound --> stand, children: []
# state --> compound --> stand, children: []
# stand --> compound --> foot, children: [suspend, state]
# ball --> compound --> foot, children: []
# foot --> nsubj --> feel, children: [death, normal, stand, ball]
# feel --> ccomp --> thought, children: [foot, wizard]
# heel --> npadvmod --> hit, children: []
# hit --> amod --> wizard, children: [heel]
# ground --> compound --> follow, children: []
# follow --> compound --> wizard, children: [ground]
# wizard --> dobj --> feel, children: [hit, follow]
# oz --> prep --> expect, children: []
# journey --> compound --> revers, children: []
# revers --> nsubj --> parallel, children: [journey]
# parallel --> ccomp --> expect, children: [revers, trailer]
# explicit --> amod --> doll, children: []
# ultim --> amod --> doll, children: []
# pinocchio --> compound --> doll, children: []
# storylin --> compound --> doll, children: []
# doll --> compound --> barbi, children: [explicit, ultim, pinocchio, storylin]
# real --> amod --> barbi, children: []
# worldif --> compound --> barbi, children: []
# barbi --> compound --> trailer, children: [doll, real, worldif]
# fulli --> compound --> trailer, children: []
# dedic --> compound --> trailer, children: []
# conceit --> compound --> trailer, children: []
# promis --> compound --> trailer, children: []
# trailer --> dobj --> parallel, children: [barbi, fulli, dedic, conceit, promis]
# could --> aux --> interest, children: []
# interest --> compound --> truman, children: [could]
# explor --> compound --> way, children: []
# way --> compound --> truman, children: [explor]
# truman --> nsubj --> show, children: [interest, way]
# show --> ccomp --> expect, children: [truman, fiction, film, happen]
# stranger --> amod --> fiction, children: []
# fiction --> dobj --> show, children: [stranger]
# instead --> advmod --> film, children: []
# film --> ccomp --> show, children: [instead, threat]
# choos --> compound --> threat, children: []
# introduc --> amod --> threat, children: []
# hand --> compound --> conflict, children: []
# conflict --> compound --> threat, children: [hand]
# threat --> dobj --> film, children: [choos, introduc, conflict]
# plotlin --> nmod --> world, children: [realis]
# never --> neg --> fulli, children: []
# fulli --> nsubj --> realis, children: [never]
# realis --> relcl --> plotlin, children: [fulli, play]
# natur --> compound --> connect, children: []
# connect --> amod --> girl, children: [natur]
# barbi --> compound --> girl, children: []
# girl --> nsubj --> play, children: [connect, barbi]
# play --> ccomp --> realis, children: [girl, doll]
# doll --> dobj --> play, children: []
# real --> amod --> world, children: []
# world --> nsubj --> happen, children: [plotlin, real]
# would --> aux --> happen, children: []
# happen --> ccomp --> show, children: [world, would, barbi, barbi]
# barbi --> dobj --> happen, children: [put]
# put --> acl --> barbi, children: [back, headquart]
# back --> prt --> put, children: []
# box --> compound --> gloria, children: []
# gloria --> compound --> ferrera, children: [box]
# america --> compound --> ferrera, children: []
# ferrera --> compound --> receptionist, children: [gloria, america]
# receptionist --> compound --> mattel, children: [ferrera]
# mattel --> compound --> headquart, children: [receptionist]
# headquart --> dobj --> put, children: [mattel]
# later --> advmod --> barbi, children: []
# barbi --> advcl --> happen, children: [later, depress, eventu, spend]
# realworld --> compound --> companion, children: []
# companion --> compound --> depress, children: [realworld]
# depress --> dobj --> barbi, children: [companion]
# eventu --> dobj --> barbi, children: []
# resolv --> compound --> gloria, children: []
# gloria --> compound --> daughter, children: [resolv]
# daughter --> compound --> mattel, children: [gloria]
# sasha --> compound --> mattel, children: []
# ariana --> compound --> mattel, children: []
# greenblatt --> compound --> mother, children: []
# cross --> compound --> mother, children: []
# mother --> compound --> board, children: [greenblatt, cross]
# board --> compound --> mattel, children: [mother]
# mattel --> nsubj --> spend, children: [daughter, sasha, ariana, board]
# spend --> ccomp --> barbi, children: [mattel, film, hide]
# one --> nummod --> film, children: []
# third --> amod --> film, children: []
# film --> dobj --> spend, children: [one, third]
# hide --> xcomp --> spend, children: [contradict]
# bush --> nmod --> kendom, children: []
# importantli --> nmod --> kendom, children: []
# crux --> compound --> conflict, children: []
# thirdact --> compound --> conflict, children: []
# conflict --> compound --> set, children: [crux, thirdact]
# set --> compound --> barbi, children: [conflict]
# barbi --> compound --> kendom, children: [set]
# land --> compound --> renam, children: []
# renam --> compound --> kendom, children: [land]
# kendom --> nsubj --> contradict, children: [bush, importantli, barbi, renam]
# contradict --> ccomp --> hide, children: [kendom, role]
# previous --> amod --> role, children: []
# establish --> compound --> world, children: []
# world --> nmod --> product, children: [establish]
# inhabitantstoward --> nmod --> product, children: []
# final --> amod --> product, children: []
# product --> nmod --> role, children: [world, inhabitantstoward, final]
# evolv --> nmod --> role, children: []
# explicit --> amod --> role, children: []
# commentari --> compound --> gender, children: []
# gender --> compound --> role, children: [commentari]
# role --> dobj --> contradict, children: [previous, product, evolv, explicit, gender, take]
# one --> nummod --> side, children: []
# side --> npadvmod --> present, children: [one]
# present --> amod --> repeatedli, children: [side]
# clueless --> amod --> manipul, children: []
# attentionseek --> compound --> manipul, children: []
# manipul --> compound --> repeatedli, children: [clueless, attentionseek]
# veng --> compound --> film, children: []
# film --> compound --> repeatedli, children: [veng]
# repeatedli --> nsubj --> take, children: [present, manipul, film]
# take --> relcl --> role, children: [repeatedli, mansplain]
# offenc --> compound --> mansplain, children: []
# mansplain --> dobj --> take, children: [offenc]
# yet --> advmod --> manner, children: []
# behav --> compound --> manner, children: []
# blith --> compound --> manner, children: []
# patronis --> compound --> manner, children: []
# manner --> nsubj --> presum, children: [yet, behav, blith, patronis, toward]
# toward --> prep --> manner, children: [support]
# viewer --> amod --> support, children: []
# much --> amod --> support, children: []
# declar --> amod --> support, children: []
# support --> pobj --> toward, children: [viewer, much, declar, shown]
# shown --> acl --> support, children: [pictur]
# pictur --> dobj --> shown, children: []
# reli --> nsubj --> presum, children: []
# presum --> ROOT --> presum, children: [manner, reli, number]
# prior --> amod --> audienc, children: []
# experi --> amod --> audienc, children: []
# audienc --> amod --> number, children: [prior, experi]
# rather --> advmod --> storytel, children: []
# storytel --> amod --> includ, children: [rather]
# denouement --> amod --> includ, children: []
# includ --> nmod --> number, children: [storytel, denouement]
# one --> nummod --> film, children: []
# film --> compound --> highlight, children: [one]
# highlight --> compound --> music, children: [film]
# music --> compound --> number, children: [highlight]
# number --> dobj --> presum, children: [audienc, includ, music]
# i --> nsubj --> m, children: []
# m --> dep --> end, children: [i]
# ken --> intj --> end, children: []
# end --> ROOT --> end, children: [m, ken]
# resolv --> amod --> acknowledg, children: []
# acknowledg --> nsubj --> perform, children: [resolv]
# much --> amod --> offensivebarbi, children: []
# final --> amod --> offensivebarbi, children: []
# scene --> compound --> reduct, children: []
# reduct --> compound --> point, children: [scene]
# point --> compound --> offensivebarbi, children: [reduct]
# offensivebarbi --> compound --> praiseworthi, children: [much, final, point]
# easi --> compound --> praiseworthi, children: []
# eye --> compound --> act, children: []
# act --> compound --> praiseworthi, children: [eye]
# rang --> compound --> praiseworthi, children: []
# compet --> compound --> praiseworthi, children: []
# inspir --> compound --> praiseworthi, children: []
# praiseworthi --> nsubj --> perform, children: [offensivebarbi, easi, act, rang, compet, inspir]
# perform --> ROOT --> perform, children: [acknowledg, praiseworthi, shine, funni, yet, charactersif, write, get, weed, miss, say, boreth, began, movi, made]
# lead --> compound --> actor, children: []
# actor --> compound --> gosl, children: [lead]
# margot --> compound --> gosl, children: []
# robbi --> compound --> gosl, children: []
# pitchperfect --> amod --> barbi, children: []
# barbi --> compound --> gosl, children: [pitchperfect]
# ryan --> compound --> gosl, children: []
# gosl --> nsubj --> shine, children: [actor, margot, robbi, barbi, ryan]
# shine --> dobj --> perform, children: [gosl, counterpart, close]
# counterpart --> dobj --> shine, children: []
# often --> advmod --> steal, children: []
# steal --> amod --> show, children: [often]
# show --> compound --> funni, children: [steal]
# situat --> compound --> funni, children: []
# comedi --> compound --> slapstick, children: []
# slapstick --> compound --> funni, children: [comedi]
# mostli --> compound --> funni, children: []
# land --> compound --> funni, children: []
# bon --> compound --> funni, children: []
# mot --> compound --> funni, children: []
# funni --> npadvmod --> perform, children: [show, situat, slapstick, mostli, land, bon, mot]
# yet --> cc --> perform, children: []
# hardli --> compound --> charactersif, children: []
# plausibl --> nmod --> charactersif, children: []
# spoken --> amod --> charactersif, children: []
# charactersif --> dobj --> perform, children: [hardli, plausibl, spoken, written]
# better --> advmod --> written, children: []
# written --> acl --> charactersif, children: [better, convert]
# joyrid --> amod --> convert, children: []
# pink --> advmod --> convert, children: []
# convert --> ccomp --> written, children: [joyrid, pink, humor]
# leav --> nmod --> mouth, children: []
# blond --> amod --> hair, children: []
# hair --> compound --> mouth, children: [blond]
# mouth --> compound --> humor, children: [leav, hair]
# qualiti --> compound --> humor, children: []
# humor --> dobj --> convert, children: [mouth, qualiti]
# write --> advcl --> perform, children: []
# movi --> compound --> quirki, children: []
# fun --> compound --> quirki, children: []
# quirki --> compound --> uniqu, children: [movi, fun]
# uniqu --> nsubj --> get, children: [quirki]
# get --> conj --> perform, children: [uniqu]
# weed --> conj --> perform, children: []
# tri --> amod --> movi, children: []
# explor --> nmod --> movi, children: []
# deeper --> amod --> movi, children: []
# theme --> compound --> movi, children: []
# movi --> nsubj --> miss, children: [tri, explor, deeper, theme]
# miss --> conj --> perform, children: [movi]
# middl --> compound --> exposit, children: []
# exposit --> compound --> phase, children: [middl]
# phase --> compound --> movi, children: [exposit]
# movi --> nsubj --> say, children: [phase]
# must --> aux --> say, children: []
# say --> conj --> perform, children: [movi, must]
# boreth --> prep --> perform, children: []
# movi --> nsubj --> close, children: []
# close --> acl --> shine, children: [movi, messag, without, give]
# great --> amod --> messag, children: []
# incap --> compound --> messag, children: []
# deliv --> compound --> messag, children: []
# messag --> dobj --> close, children: [great, incap, deliv]
# without --> prep --> close, children: [liter]
# charact --> compound --> liter, children: []
# liter --> pobj --> without, children: [charact]
# give --> conj --> close, children: [speech]
# speech --> dobj --> give, children: [worth]
# worth --> amod --> speech, children: []
# dialoguewhat --> nsubj --> began, children: []
# could --> aux --> began, children: []
# great --> amod --> satir, children: []
# satir --> nsubj --> began, children: [great]
# began --> conj --> perform, children: [dialoguewhat, could, satir, turn]
# cleverli --> amod --> movi, children: []
# funni --> compound --> movi, children: []
# movi --> nsubj --> turn, children: [cleverli, funni]
# turn --> ccomp --> began, children: [movi, guess]
# preachi --> amod --> end, children: []
# moral --> amod --> movi, children: []
# movi --> compound --> end, children: [moral]
# end --> nsubj --> guess, children: [preachi, movi]
# guess --> ccomp --> turn, children: [end, charm]
# charm --> dobj --> guess, children: [first]
# first --> advmod --> charm, children: []
# half --> amod --> movi, children: []
# movi --> dobj --> perform, children: [half]
# made --> dep --> perform, children: [give]
# shortcom --> compound --> pain, children: []
# much --> amod --> pain, children: []
# pain --> nsubj --> give, children: [shortcom, much]
# give --> ccomp --> made, children: [pain, give]
# movi --> compound --> call, children: []
# call --> compound --> barbi, children: [movi]
# barbi --> compound --> craft, children: [call]
# brilliantli --> nmod --> handl, children: []
# handl --> nmod --> craft, children: [brilliantli]
# fine --> amod --> craft, children: []
# craft --> nsubj --> give, children: [barbi, handl, fine]
# give --> ccomp --> give, children: [craft, credit, ye, offic]
# filmak --> compound --> credit, children: []
# credit --> dobj --> give, children: [filmak]
# ye --> dative --> give, children: [person]
# somewhat --> advmod --> conserv, children: []
# conserv --> compound --> person, children: [somewhat]
# person --> pobj --> ye, children: [conserv]
# former --> amod --> law, children: []
# law --> compound --> offic, children: [former]
# enforc --> compound --> offic, children: []
# offic --> dative --> give, children: [law, enforc]
# i --> nsubj --> enjoy, children: [m, guy]
# m --> appos --> i, children: []
# guy --> appos --> i, children: [like]
# like --> prep --> guy, children: [thing]
# guy --> compound --> thing, children: []
# thing --> pobj --> like, children: [guy]
# hell --> nsubj --> enjoy, children: []
# even --> advmod --> enjoy, children: []
# enjoy --> ROOT --> enjoy, children: [i, hell, even, absolut, spade, pretti, wife, humor]
# battleship --> compound --> movi, children: []
# movi --> compound --> year, children: [battleship]
# year --> npadvmod --> ago, children: [movi]
# ago --> advmod --> absolut, children: [year]
# absolut --> advcl --> enjoy, children: [ago, ridicul]
# ridicul --> xcomp --> absolut, children: [film, like]
# fun --> compound --> film, children: []
# romp --> compound --> film, children: []
# action --> compound --> film, children: []
# film --> dobj --> ridicul, children: [fun, romp, action]
# also --> advmod --> like, children: []
# like --> prep --> ridicul, children: [also, deliv]
# experi --> amod --> man, children: []
# perspect --> compound --> man, children: []
# man --> nmod --> movi, children: [experi, perspect, oh]
# oh --> cc --> man, children: []
# man --> compound --> movi, children: []
# movi --> compound --> deliv, children: [man, man]
# deliv --> pobj --> like, children: [movi]
# spade --> advmod --> enjoy, children: []
# pretti --> punct --> enjoy, children: []
# much --> amod --> encapsul, children: []
# encapsul --> compound --> wife, children: [much]
# everyth --> compound --> wife, children: []
# wife --> npadvmod --> enjoy, children: [encapsul, everyth, life]
# tri --> compound --> life, children: []
# convey --> compound --> life, children: []
# entir --> compound --> career, children: []
# career --> compound --> life, children: [entir]
# life --> appos --> wife, children: [tri, convey, career]
# experi --> compound --> wrap, children: []
# wrap --> nmod --> humor, children: [experi]
# two --> nummod --> hour, children: []
# hour --> compound --> humor, children: [two]
# humor --> dobj --> enjoy, children: [wrap, hour, set, stori]
# set --> acl --> humor, children: []
# act --> compound --> weav, children: []
# abil --> compound --> weav, children: []
# weav --> nmod --> stori, children: [act, abil]
# current --> amod --> stori, children: []
# narr --> amod --> stori, children: []
# stori --> appos --> humor, children: [weav, current, narr, perfect]
# perfect --> amod --> stori, children: []
# do --> aux --> agre, children: [nt]
# nt --> punct --> do, children: []
# agre --> compound --> point, children: [do]
# point --> compound --> movi, children: [agre]
# movi --> nsubj --> give, children: [point, was]
# that --> nsubj --> was, children: [ok]
# ok --> prep --> that, children: [movi]
# movi --> pobj --> ok, children: []
# was --> relcl --> movi, children: [that, nt]
# nt --> neg --> was, children: []
# design --> compound --> give, children: []
# give --> compound --> noholdsbar, children: [movi, design, men]
# balanc --> compound --> men, children: []
# perspect --> compound --> men, children: []
# men --> dative --> give, children: [balanc, perspect]
# versu --> compound --> woman, children: []
# woman --> compound --> noholdsbar, children: [versu]
# noholdsbar --> compound --> sinc, children: [give, woman]
# unapologet --> compound --> sinc, children: []
# crazi --> compound --> woman, children: []
# ride --> nmod --> woman, children: []
# rant --> nmod --> woman, children: []
# real --> amod --> woman, children: []
# issu --> compound --> woman, children: []
# woman --> compound --> sinc, children: [crazi, ride, rant, real, issu]
# face --> compound --> sinc, children: []
# sinc --> nsubj --> allow, children: [noholdsbar, unapologet, woman, face]
# allow --> ROOT --> allow, children: [sinc, give, make, see, lost, get, is, add, enjoy, expect, expect, see, miss, expect, made]
# real --> amod --> thing, children: []
# job --> compound --> thing, children: []
# thing --> compound --> men, children: [real, job]
# men --> nsubj --> give, children: [thing]
# give --> ccomp --> allow, children: [men]
# well --> advmod --> done, children: []
# done --> amod --> watch, children: [well]
# film --> compound --> blast, children: []
# blast --> compound --> watch, children: [film]
# watch --> nsubj --> make, children: [done, blast]
# make --> ccomp --> allow, children: [watch, think]
# think --> ccomp --> make, children: [grew]
# done --> amod --> woman, children: []
# place --> compound --> detail, children: []
# creativ --> compound --> passion, children: []
# passion --> compound --> attent, children: [creativ]
# attent --> compound --> detail, children: [passion]
# detail --> compound --> call, children: [place, attent]
# ill --> compound --> call, children: []
# call --> compound --> woman, children: [detail, ill]
# masterpiec --> amod --> woman, children: []
# woman --> nsubj --> grew, children: [done, call, masterpiec]
# grew --> ccomp --> think, children: [woman]
# barbi --> nsubj --> see, children: [curiou]
# excit --> amod --> curiou, children: []
# movi --> compound --> curiou, children: []
# curiou --> appos --> barbi, children: [excit, movi]
# see --> ccomp --> allow, children: [barbi, evolv]
# would --> aux --> evolv, children: []
# evolv --> ccomp --> see, children: [would]
# stereotyp --> compound --> barbi, children: []
# barbi --> compound --> complet, children: [stereotyp]
# someth --> amod --> movi, children: []
# messag --> compound --> movi, children: []
# movi --> compound --> complet, children: [someth, messag]
# heavi --> compound --> complet, children: []
# hand --> compound --> complet, children: []
# complet --> nsubj --> lost, children: [barbi, movi, heavi, hand]
# lost --> ccomp --> allow, children: [complet, gender, equal, get]
# plot --> compound --> gender, children: []
# consid --> nmod --> gender, children: []
# propon --> compound --> gender, children: []
# gender --> dobj --> lost, children: [plot, consid, propon]
# equal --> advcl --> lost, children: []
# ai --> aux --> get, children: [nt]
# nt --> neg --> ai, children: []
# way --> npadvmod --> get, children: []
# get --> advcl --> lost, children: [ai, way, give]
# itbarbieland --> compound --> patriarchi, children: []
# flip --> compound --> patriarchi, children: []
# script --> compound --> patriarchi, children: []
# patriarchi --> nmod --> world, children: [itbarbieland, flip, script]
# real --> amod --> world, children: []
# world --> nsubj --> give, children: [patriarchi, real]
# give --> ccomp --> get, children: [world, power, attract]
# woman --> compound --> power, children: []
# power --> dobj --> give, children: [woman]
# leav --> compound --> attract, children: []
# ken --> compound --> attract, children: []
# attract --> dobj --> give, children: [leav, ken]
# accessori --> intj --> get, children: []
# ken --> nsubj --> get, children: []
# get --> ccomp --> allow, children: [accessori, ken, bring]
# glimps --> nmod --> world, children: []
# real --> amod --> world, children: []
# world --> nsubj --> bring, children: [glimps, real]
# bring --> ccomp --> get, children: [world, brainwash, suddenli]
# patriarchi --> compound --> barbieland, children: []
# barbieland --> compound --> barbi, children: [patriarchi]
# barbi --> compound --> brainwash, children: [barbieland]
# brainwash --> dobj --> bring, children: [barbi]
# happen --> compound --> suddenli, children: []
# ...
# head --> npadvmod --> steal, children: []
# steal --> dep --> hit, children: [head, scene]
# everi --> amod --> scene, children: []
# scene --> dobj --> steal, children: [everi, board]
# he --> nsubj --> board, children: []
# would --> aux --> board, children: []
# board --> relcl --> scene, children: [he, would, liu, also, role]
# ken --> compound --> ferrara, children: []
# spinoff --> compound --> ferrara, children: []
# america --> compound --> ferrara, children: []
# ferrara --> compound --> simu, children: [ken, spinoff, america]
# simu --> compound --> liu, children: [ferrara]
# liu --> dobj --> board, children: [simu]
# also --> advmod --> board, children: []
# great --> amod --> role, children: []
# respect --> compound --> role, children: []
# role --> dobj --> board, children: [great, respect, cast]
# cast --> acl --> role, children: [barbi]
# overal --> amod --> barbi, children: []
# perfect --> amod --> barbi, children: []
# overal --> amod --> barbi, children: []
# barbi --> dobj --> cast, children: [overal, perfect, overal]
# probabl --> amod --> movi, children: []
# best --> amod --> toy, children: []
# movi --> compound --> toy, children: []
# base --> compound --> toy, children: []
# toy --> compound --> movi, children: [best, movi, base]
# sorri --> nmod --> movi, children: []
# lego --> compound --> movi, children: []
# movi --> dobj --> hit, children: [probabl, toy, sorri, lego, movi, enjoy]
# overal --> amod --> time, children: []
# fantast --> compound --> time, children: []
# time --> compound --> movi, children: [overal, fantast]
# movi --> appos --> movi, children: [time]
# mr --> compound --> shullivan, children: []
# shullivan --> nsubj --> enjoy, children: [mr]
# enjoy --> relcl --> movi, children: [shullivan]
# first --> compound --> minut, children: []
# minut --> nmod --> length, children: [first]
# full --> amod --> length, children: []
# length --> nmod --> variou, children: [minut, full]
# featur --> nmod --> film, children: []
# film --> nmod --> song, children: [featur]
# third --> amod --> song, children: []
# song --> compound --> variou, children: [film, third]
# danc --> compound --> variou, children: []
# number --> compound --> variou, children: []
# variou --> compound --> gosl, children: [length, song, danc, number]
# ken --> compound --> gosl, children: []
# agre --> compound --> gosl, children: []
# ryan --> compound --> gosl, children: []
# gosl --> nsubj --> appear, children: [variou, ken, agre, ryan]
# appear --> conj --> get, children: [gosl, get]
# main --> amod --> barbiedont, children: []
# charact --> compound --> barbiedont, children: []
# barbiedont --> nsubj --> get, children: [main, charact]
# get --> ccomp --> appear, children: [barbiedont, doll]
# wrong --> amod --> doll, children: []
# ryan --> compound --> gosl, children: []
# gosl --> compound --> doll, children: [ryan]
# margot --> compound --> doll, children: []
# robbi --> compound --> doll, children: []
# perform --> compound --> doll, children: []
# respect --> compound --> doll, children: []
# doll --> dobj --> get, children: [wrong, gosl, margot, robbi, perform, respect, like]
# like --> prep --> doll, children: [barbi]
# roll --> compound --> barbi, children: []
# ken --> compound --> barbi, children: []
# barbi --> pobj --> like, children: [roll, ken]
# well --> compound --> balanc, children: []
# balanc --> nsubj --> comed, children: [well]
# comed --> conj --> get, children: [balanc, appear]
# realist --> compound --> produc, children: []
# deliveri --> compound --> produc, children: []
# produc --> nsubj --> appear, children: [realist, deliveri]
# appear --> ccomp --> comed, children: [produc, enhanc]
# display --> compound --> gosl, children: []
# ryan --> compound --> gosl, children: []
# gosl --> compound --> doll, children: [display, ryan]
# ken --> compound --> doll, children: []
# doll --> nsubj --> enhanc, children: [gosl, ken]
# enhanc --> ccomp --> appear, children: [doll]
# cgi --> compound --> bicep, children: []
# eight --> nummod --> pack, children: []
# pack --> compound --> bulg, children: [eight]
# abdomen --> compound --> bulg, children: []
# bulg --> compound --> bicep, children: [pack, abdomen]
# bicep --> nsubj --> thought, children: [cgi, bulg]
# thought --> advcl --> get, children: [bicep, reflect, seem, see]
# vaniti --> compound --> gosl, children: []
# project --> compound --> gosl, children: []
# ryan --> compound --> gosl, children: []
# gosl --> nsubj --> reflect, children: [vaniti, project, ryan, opportun]
# rather --> advmod --> opportun, children: []
# opportun --> appos --> gosl, children: [rather]
# reflect --> ccomp --> thought, children: [gosl, worldth]
# chang --> compound --> world, children: []
# world --> compound --> advanc, children: [chang]
# advanc --> compound --> vision, children: [world]
# femin --> compound --> barbi, children: []
# barbi --> compound --> vision, children: [femin]
# vision --> compound --> chang, children: [advanc, barbi]
# chang --> nsubj --> worldth, children: [vision]
# worldth --> ccomp --> reflect, children: [chang, elvi]
# visual --> amod --> pastel, children: []
# multi --> nmod --> pastel, children: []
# color --> compound --> pastel, children: []
# pastel --> compound --> film, children: [visual, multi, color]
# remind --> compound --> elvi, children: []
# elvi --> compound --> film, children: [remind]
# film --> compound --> barbi, children: [pastel, elvi]
# blue --> compound --> barbi, children: []
# hawaii --> compound --> barbi, children: []
# sinc --> compound --> barbi, children: []
# barbi --> nsubj --> elvi, children: [film, blue, hawaii, sinc]
# elvi --> ccomp --> worldth, children: [barbi, icon, within]
# popular --> amod --> icon, children: []
# icon --> dobj --> elvi, children: [popular]
# within --> prep --> elvi, children: [man]
# era --> compound --> downsid, children: []
# downsid --> compound --> barbi, children: [era]
# barbi --> compound --> man, children: [downsid]
# film --> nmod --> person, children: []
# messag --> compound --> person, children: []
# person --> npadvmod --> reliant, children: [film, messag]
# reliant --> amod --> man, children: [person]
# man --> pobj --> within, children: [barbi, reliant]
# seem --> ccomp --> thought, children: [male, perform]
# get --> compound --> male, children: []
# lost --> amod --> song, children: []
# multipl --> compound --> song, children: []
# song --> compound --> male, children: [lost, multipl]
# danc --> compound --> ensembl, children: []
# number --> compound --> ensembl, children: []
# provid --> compound --> ensembl, children: []
# ensembl --> npadvmod --> cast, children: [danc, number, provid]
# cast --> compound --> male, children: [ensembl]
# male --> xcomp --> seem, children: [get, song, cast]
# ken --> nmod --> dollsal, children: []
# dollsal --> compound --> decent, children: [ken]
# decent --> amod --> film, children: [dollsal]
# film --> nmod --> futur, children: [decent]
# consid --> amod --> futur, children: []
# futur --> compound --> film, children: [film, consid]
# film --> compound --> goslng, children: [futur]
# classic --> compound --> goslng, children: []
# memor --> compound --> ryan, children: []
# ryan --> compound --> goslng, children: [memor]
# goslng --> nsubj --> perform, children: [film, classic, ryan]
# margot --> nsubj --> perform, children: []
# robbi --> nsubj --> perform, children: []
# perform --> xcomp --> seem, children: [goslng, margot, robbi, award, like]
# worthi --> compound --> award, children: []
# academi --> compound --> award, children: []
# award --> dobj --> perform, children: [worthi, academi]
# like --> prep --> perform, children: [rememb]
# barbi --> nsubj --> rememb, children: []
# may --> aux --> rememb, children: []
# rememb --> pcomp --> like, children: [barbi, may, today, time, era]
# today --> npadvmod --> rememb, children: []
# memor --> compound --> place, children: []
# place --> compound --> time, children: [memor]
# time --> npadvmod --> rememb, children: [place]
# long --> amod --> era, children: []
# past --> amod --> era, children: []
# era --> npadvmod --> rememb, children: [long, past]
# would --> aux --> see, children: []
# surpris --> nsubj --> see, children: []
# see --> ccomp --> thought, children: [would, surpris, turn, hold]
# tv --> compound --> produc, children: []
# produc --> nsubj --> turn, children: [tv]
# turn --> ccomp --> see, children: [produc, film]
# barbi --> compound --> film, children: []
# film --> dobj --> turn, children: [barbi]
# franchis --> det --> opinion, children: []
# merchandis --> compound --> weekli, children: []
# bonanza --> compound --> weekli, children: []
# weekli --> compound --> sitcom, children: [merchandis, bonanza]
# minut --> compound --> sitcom, children: []
# tv --> compound --> sitcom, children: []
# sitcom --> compound --> opinion, children: [weekli, minut, tv]
# humbl --> compound --> opinion, children: []
# opinion --> nsubj --> hold, children: [franchis, sitcom, humbl]
# could --> aux --> hold, children: []
# hold --> ccomp --> see, children: [opinion, could, give]
# mr --> compound --> fori, children: []
# shullivan --> compound --> fori, children: []
# attent --> compound --> fori, children: []
# fori --> nsubj --> give, children: [mr, shullivan, attent]
# give --> ccomp --> hold, children: [fori, film, thought]
# film --> dative --> give, children: []
# decent --> amod --> lot, children: []
# imdb --> compound --> rate, children: []
# rate --> compound --> play, children: [imdb]
# play --> compound --> barbi, children: [rate]
# barbi --> compound --> lot, children: [play]
# lot --> compound --> kid, children: [decent, barbi]
# kid --> nsubj --> thought, children: [lot]
# thought --> ccomp --> give, children: [kid, go]
# movi --> nsubj --> go, children: []
# go --> ccomp --> thought, children: [movi, look, thought]
# fun --> compound --> trailer, children: []
# trailer --> compound --> look, children: [fun]
# look --> npadvmod --> go, children: [trailer]
# great --> amod --> thought, children: []
# thought --> npadvmod --> go, children: [great]
# let --> advcl --> get, children: [relax, let]
# girl --> compound --> kick, children: []
# movi --> compound --> night, children: []
# night --> compound --> kick, children: [movi]
# kick --> nsubj --> relax, children: [girl, night]
# back --> advmod --> relax, children: []
# relax --> ccomp --> let, children: [kick, back]
# watch --> compound --> greatli, children: []
# funni --> compound --> movi, children: []
# icon --> compound --> movi, children: []
# movi --> compound --> toy, children: [funni, icon]
# favorit --> compound --> toy, children: []
# toy --> compound --> greatli, children: [movi, favorit]
# kid --> compound --> greatli, children: []
# greatli --> nsubj --> let, children: [watch, toy, kid]
# let --> ccomp --> let, children: [greatli]
# realli --> nsubj --> movi, children: []
# fast --> amod --> movi, children: []
# movi --> nmod --> role, children: [realli, fast]
# strong --> amod --> man, children: []
# messag --> compound --> woman, children: []
# woman --> compound --> man, children: [messag]
# man --> compound --> role, children: [strong, woman]
# world --> compound --> defin, children: []
# defin --> compound --> role, children: [world]
# role --> conj --> get, children: [movi, man, defin, made]
# whoever --> dobj --> made, children: []
# noth --> compound --> movi, children: []
# movi --> nsubj --> made, children: [noth]
# made --> relcl --> role, children: [whoever, movi, felt]
# laugh --> nsubj --> felt, children: []
# felt --> ccomp --> made, children: [laugh, tell]
# kinda --> amod --> messag, children: []
# heavi --> compound --> messag, children: []
# messag --> nsubj --> tell, children: [kinda, heavi]
# tell --> ccomp --> felt, children: [messag, movi]
# definit --> compound --> movi, children: []
# kid --> compound --> movi, children: []
# movi --> dobj --> tell, children: [definit, kid]
# either --> preconj --> think, children: []
# do --> aux --> think, children: []
# nt --> neg --> think, children: []
# think --> conj --> get, children: [either, do, nt, understand, enjoy]
# would --> aux --> understand, children: []
# understand --> ccomp --> think, children: [would, was]
# half --> amod --> realli, children: []
# realli --> nsubj --> was, children: [half]
# was --> ccomp --> understand, children: [realli, nt]
# nt --> neg --> was, children: []
# happi --> compound --> movi, children: []
# movi --> compound --> realli, children: [happi]
# realli --> nsubj --> enjoy, children: [movi]
# enjoy --> ccomp --> think, children: [realli, becam]
# first --> compound --> movi, children: []
# minut --> compound --> movi, children: []
# movi --> compound --> thing, children: [first, minut]
# upbeat --> amod --> posit, children: []
# posit --> compound --> thing, children: [upbeat]
# light --> compound --> howev, children: []
# howev --> compound --> thing, children: [light]
# thing --> nsubj --> becam, children: [movi, posit, howev]
# soon --> advmod --> becam, children: []
# becam --> ccomp --> enjoy, children: [thing, soon, stand]
# neg --> compound --> minut, children: []
# minut --> compound --> movi, children: [neg]
# movi --> nsubj --> stand, children: [minut]
# could --> aux --> stand, children: []
# nt --> neg --> stand, children: []
# stand --> ccomp --> becam, children: [movi, could, nt, sour]
# barbi --> compound --> bummer, children: []
# world --> nmod --> bummer, children: []
# attitud --> amod --> bummer, children: []
# constant --> amod --> bummer, children: []
# bummer --> compound --> ken, children: [barbi, world, attitud, constant]
# ken --> compound --> sour, children: [bummer]
# attitud --> compound --> sour, children: []
# sour --> dobj --> stand, children: [ken, attitud]
# next --> amod --> hour, children: []
# hour --> compound --> movi, children: [next]
# movi --> compound --> negativityi, children: [hour]
# live --> compound --> negativityi, children: []
# negativityi --> nsubj --> bought, children: [movi, live]
# bought --> conj --> get, children: [negativityi, ago, saw, need]
# ticket --> compound --> show, children: []
# show --> compound --> month, children: [ticket]
# month --> npadvmod --> ago, children: [show]
# ago --> advmod --> bought, children: [month]
# saw --> advcl --> bought, children: [day, play, look]
# day --> dobj --> saw, children: [offici]
# offici --> npadvmod --> day, children: []
# open --> amod --> day, children: []
# day --> compound --> movi, children: [open]
# excit --> compound --> movi, children: []
# movi --> nsubj --> play, children: [day, excit]
# play --> ccomp --> saw, children: [movi, music, dua]
# music --> dobj --> play, children: []
# dua --> dobj --> play, children: [song]
# lipa --> amod --> song, children: []
# song --> dobj --> dua, children: [lipa]
# almost --> advmod --> everi, children: []
# everi --> amod --> movi, children: [almost]
# day --> compound --> movi, children: []
# realli --> compound --> movi, children: []
# excit --> compound --> movi, children: []
# movi --> nsubj --> look, children: [everi, day, realli, excit]
# look --> ccomp --> saw, children: [movi, forward, write]
# forward --> advmod --> look, children: []
# someth --> amod --> posit, children: []
# posit --> nmod --> part, children: [someth]
# vast --> amod --> part, children: []
# major --> amod --> part, children: []
# movi --> compound --> part, children: []
# conflict --> compound --> part, children: []
# part --> nsubj --> write, children: [posit, vast, major, movi, conflict]
# write --> advcl --> look, children: [part, movi]
# much --> amod --> movi, children: []
# movi --> dobj --> write, children: [much]
# did --> aux --> need, children: []
# nt --> neg --> need, children: []
# need --> advcl --> bought, children: [did, nt, go]
# go --> xcomp --> need, children: [fast]
# way --> advmod --> far, children: []
# far --> advmod --> fast, children: [way]
# fast --> advmod --> go, children: [far]
# would --> aux --> prefer, children: []
# prefer --> conj --> get, children: [would, conflict]
# shallow --> amod --> fun, children: []
# fun --> compound --> barbi, children: [shallow]
# barbi --> compound --> movi, children: [fun]
# movi --> compound --> movi, children: []
# v --> compound --> barbi, children: []
# barbi --> compound --> movi, children: [v]
# movi --> nsubj --> fill, children: [barbi, movi, barbi]
# fill --> compound --> hour, children: [movi]
# hour --> compound --> conflict, children: [fill]
# conflict --> dobj --> prefer, children: [hour]
# Named Entities:
# GPE: 6
# PERSON: 59
# ORDINAL: 11
# CARDINAL: 21
# DATE: 9
# EVENT: 1
# ORG: 31
# NORP: 7
# PRODUCT: 1
# TIME: 4

# %% [markdown]
# In this parse tree of constituencies:
#
# This sentence is represented by the root node "S."
# The verbs "given" and "quirki," together with their corresponding objects and modifiers, make up the primary verb phrase (VP).
# The noun phrase (NP) consists of the past participle "given" with nouns such as "film," "market," and "fun."
# Adjectives such as "quirki" and "best" are connected to the nouns they describe.
# The verb "overdramat" is modified by the prepositional phrase "in a paragraph."
#
# In this parsing tree of dependencies:
#
# Dependencies exist between the basic verb "given" and the nouns "film" and "market."
# Adjectives such as "quirki" and "best" are dependent on the nouns they describe.
# The word "disappoint" depends on the word "film."
# There are dependencies between the nouns "fun," "satir," "homag," and "movi" and the main verb "quirki."
# The preposition "in" depends on the word "overdramat," and "a paragraph" changes the word "overdramat."

# %% [markdown]
# # Mandatory Question
#
# Provide your thoughts on the assignment. What did you find challenging, and what aspects did you enjoy? Your opinion on the provided time to complete the assignment.

# %% [markdown]
# I find it challenging working with csv files and it is difficult to work with them.I enjoy working with python libraries.I think provided time is not enough to work with the assignment.
